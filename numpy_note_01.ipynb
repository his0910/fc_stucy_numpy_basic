# %%
# shape : 차원의 수
# (3, ) => 3 x 1의 배열
# (4, 3) => 4 x 3의 배열
# (2, 5, 3) => 2 x 5 x 3의 배열

# axis : 기준이 되는 축(앞에서부터 0, 1, 2, ,,,)

# ndarray에서 shape와 axis의 개념은 반드시 알아야 함

# %% [markdown]
# ## 1. Numpy import 하기

# %%
import numpy

# %%
numpy
# Out:
# <module 'numpy' from '/usr/local/lib/python3.7/dist-packages/numpy/__init__.py'>

# %% [markdown]
# ### 1-1. 별칭 (alias) 지정하기 (항상 해주세요!)

# %%
import numpy as np

# %%
np
# Out:
# <module 'numpy' from '/usr/local/lib/python3.7/dist-packages/numpy/__init__.py'>

# %% [markdown]
# ## 2. ndarray 생성하기

# %%
arr = np.array([1, 2, 3, 4], dtype=int)

# %%
arr
# Out:
# array([1, 2, 3, 4])

# %%
[1, 2, 3, 4]
# Out:
# [1, 2, 3, 4]

# %%
type(arr)
# Out:
# numpy.ndarray

# %% [markdown]
# ### 2-1. list로 부터 생성하기

# %%
mylist1 = [1, 2, 3, 4]

# %%
mylist2 = [[1, 2, 3, 4], 
           [5, 6, 7, 8]]

# %%
arr1 = np.array(mylist1)

# %%
arr2 = np.array(mylist2)

# %% [markdown]
# ### 2-2. shape확인하기

# %%
arr1.shape
# Out:
# (4,)

# %%
arr2.shape
# Out:
# (2, 4)

# %% [markdown]
# ## 3. array에서의 data 타입

# %% [markdown]
# array에서는 list와는 다르게 1개의 **단일 데이터 타입**만 허용 됩니다.

# %% [markdown]
# ### 3-1. list에서의 data 타입

# %%
mylist = [1, 3.14, '테디', '1234']

# %%
mylist[1]
# Out:
# 3.14

# %%
mylist[2]
# Out:
# '테디'

# %% [markdown]
# ### 3-2. array에서의 data 타입 (case를 통한 연구)

# %% [markdown]
# ### case 1. int와 float 타입이 혼재된 경우

# %%
arr = np.array([1, 2, 3, 3.14])

# %%
arr
# Out:
# array([1.  , 2.  , 3.  , 3.14])

# %%
# 정수 1, 2, 3이 각각 실수 1.0 2.0 3.0 으로 바뀌었다!

# %% [markdown]
# ### case 2. int와 float 타입이 혼재되었으나, dtype을 지정한 경우

# %%
arr = np.array([1, 2, 3, 3.14], dtype=int)

# %%
arr
# Out:
# array([1, 2, 3, 3])

# %% [markdown]
# ### case 3. int와 str 타입이 혼재된 경우

# %%
arr = np.array([1, 3.14, '테디', '1234'])

# %%
arr
# Out:
# array(['1', '3.14', '테디', '1234'], dtype='<U32')

# %%
# 정수와 실수가 각각 문자열로 바뀐거!!

# %%
arr[0] + arr[1]
# Out:
# '13.14'

# %% [markdown]
# ### case 4. int와 str 타입이 혼재되어 있고 int로 dtype을 지정한 경우

# %%
arr = np.array([1, 3.14, '테디', '1234'], dtype=int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-49dc9b2ee14e> in <module>()
# ----> 1 arr = np.array([1, 3.14, '테디', '1234'], dtype=int)
#
# ValueError: invalid literal for int() with base 10: '테디'

# %%
arr
# Out:
# array([   1,    3, 1234])
